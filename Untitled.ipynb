# %%
# Import the visualization code
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# %% [markdown]
# Question 1
# In the default simulation the Smartcab is initially stopped at a red light and does not move at all. As the simulation progresses the traffic light cycles through green and red and this changes the rewards even for the stationary Smartcab. The agent is penalized for remaining stopped at a green light and rewarded for being stopped at a red light, so reward points cycle back and forth between
# Does the Smartcab move at all during the simulation?
# What kind of rewards is the driving agent receiving?
# How does the light changing color affect the rewards?

# %% [markdown]
# In the agent.py Python file, choose three flags that can be set and explain how they change the simulation.
# In the environment.py Python file, what Environment class function is called when an agent performs an action?
# In the simulator.py Python file, what is the difference between the 'render_text()' function and the 'render()' function?
# In the planner.py Python file, will the 'next_waypoint() function consider the North-South or East-West direction first?
#
# Flags in agent.py represent different parameters for the running of the simulation.
# num_dummies sets the number of other cars driving around.
# grid_size represents the number of blocks
# Verbose allows additional informatio nto be displayed. In the default simulation, setting this flag to True adds information about the oncoming traffic at each step.

# %%
# Load the 'sim_no-learning' log file from the initial simulation results
vs.plot_trials('sim_no-learning.csv')

# %% [markdown]
# lights = state[0]['light']
# oncoming = ((state[0]['onc'] == 'Forward') or (state[0]['onc'] == 'Right'))
# leftc = (state[0]['left'] == 'Forward')
# rightc = (state[0]['right'] == 'Forward')
#
# newstates = lights,oncoming,leftc,rightc
#
# statedic = dict()
#
# for j in ('G','R'):
#     for k in (0,1):
#         for l in (0,1):
#             for m in (0,1):
#                 q = (x,y,z,w)
#                 i=i+1
#                 statedic[q] = 'State {}'.format(i)
#
# actiondic = {y:0 for y in (None,'forward','left','right')}
# QQ = {x:actiondic for x in statedic.values()}

# %%
# Load the 'sim_default-learning' file from the default Q-Learning simulation
vs.plot_trials('sim_default-learning.csv')
